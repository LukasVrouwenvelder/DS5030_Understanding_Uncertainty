# %% [markdown]
# # Week 11 — Linear Regression
#
# **DS 5030 — Understanding Uncertainty** · Fall 2026
# **Meets:** Tu/Th 11:00am–12:15pm · Section 002, SDS 406
# **Everything due:** Problem Set 10 + Lab 10 — Wed Nov 11
#
# ---
#
# > **Screen-free Tuesday.** Concepts days are discussion-based — take notes on paper, then transcribe the keepers into Key Concepts afterward. That second pass is the review.
#
# ### How to use this notebook
#
# One section per class session below. During class: **Key concepts** in your own words, **code cell** to type along, **Questions** for anything to take to office hours. A blank section is information too.
#
# ---

# %% [markdown]
# ## Thu Nov 5 — Linear Regression
#
# `Applications day / lab`
#
# > No class Tue Nov 3 — Election Day.
#
# **Key concepts**
#
# -
#
# **Worked example / what confused me**
#
# -

# %%
# Thu Nov 5 — live coding / scratch

# %% [markdown]
# **Questions / follow-up**
#
# -
#
# ---

# %% [markdown]
# ## End-of-module review
#
# **Three things I could explain to someone else**
#
# 1.
# 2.
# 3.
#
# **Still shaky on**
#
# -
#
# **Connects to** (other courses, earlier modules)
#
# -
